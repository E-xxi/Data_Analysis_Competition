# %% [markdown]
# # completed : 수료 여부 (0 ,1) 예측

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import torch
import seaborn as sns
import ast
#!pip install catboost

# %%
df_train = pd.read_csv('TrainData/train.csv')
df_train = df_train.drop('ID', axis=1)

df_test = pd.read_csv('OriginalData/test.csv')
df_test = df_test.drop('ID', axis=1)

df_train.head()
# Out:
#    generation  school1               major type       major1_1       major1_2  \
# 0           9       22  복수 전공 ( 다중전공, 이중전공 포함 )          경제통상학           자연과학
# 1           9        1  복수 전공 ( 다중전공, 이중전공 포함 )           자연과학  IT(컴퓨터 공학 포함)
# 2           9       27                    단일 전공            예체능            NaN
# 3           9        1  복수 전공 ( 다중전공, 이중전공 포함 )           사회과학  IT(컴퓨터 공학 포함)
# 4           9       16  복수 전공 ( 다중전공, 이중전공 포함 )  IT(컴퓨터 공학 포함)  IT(컴퓨터 공학 포함)
#
#    major_data  job  class1  class2  class3  ...   incumbents_company_level  \
# 0       False  대학생       1     4.0     NaN  ...                해외 기업 (빅테크)
# 1        True  대학생       8     NaN     NaN  ...     국내 빅테크 IT 계열 (네카라쿠배당토)
# 2       False  대학생       7     NaN     NaN  ...  국내 대기업 IT 계열 (금융, 제조 ...)
# 3       False  대학생       7     NaN     NaN  ...     국내 빅테크 IT 계열 (네카라쿠배당토)
# 4        True  대학생       8     NaN     NaN  ...  국내 대기업 IT 계열 (금융, 제조 ...)
#
#   incumbents_lecture_type   incumbents_lecture_scale  \
# 0              온, 오프라인 동시  100명 이상의 리스너와 10명 이상의 현직자
# 1                    오프라인  3~50명 내외의 강의 리스너와 1명의 현직자
# 2                    오프라인  3~50명 내외의 강의 리스너와 1명의 현직자
# 3              온, 오프라인 동시  3~50명 내외의 강의 리스너와 1명의 현직자
# 4              온, 오프라인 동시  3~50명 내외의 강의 리스너와 1명의 현직자
#
#                      incumbents_lecture_scale_reason interested_company  \
# 0                       다양한 사람들과 만나서 생각을 교류할 수 있기 때문   구글 딥마인드, 카카오 브레인
# 1   더 많은 사람들이 있으면 제가 예상하지 못한 질문도 할 수 있다고 생각하기 때문입니다.              제일 기획
# 2  인원이 너무 적으면 서로 부담스러울 수 있을 것 같지만 너무 많으면 너무 피상적인 ...               Lg전자
# 3                          너무 많은 인원이 강의하면 루즈해질 것 같아서                네이버
# 4                           다양한 사람들에게 기회가 있으면 좋겠습니다.                네이버
#
#                                      expected_domain contest_participation  \
# 0                                M. 전문, 과학 및 기술 서비스업                   NaN
# 1                   J. 정보통신업, O. 공공 행정, 국방 및 사회보장 행정                   NaN
# 2        C. 제조업, K. 금융 및 보험업, R. 예술, 스포츠 및 여가관련 서비스업                   NaN
# 3                              J. 정보통신업, K. 금융 및 보험업                   NaN
# 4  K. 금융 및 보험업, M. 전문, 과학 및 기술 서비스업, R. 예술, 스포츠 및...                   NaN
#
#   idea_contest                                  onedayclass_topic completed
# 0          NaN  Python 응용, 데이터 시각화 (Matplotlib, Seaborn 등), 머신...         0
# 1          NaN                                      머신러닝 / 딥러닝 응용         0
# 2          NaN                       머신러닝 / 딥러닝 응용, SQL 응용, 웹 크롤링         0
# 3          NaN                                      머신러닝 / 딥러닝 응용         1
# 4          NaN                       머신러닝 / 딥러닝 응용, SQL 응용, 웹 크롤링         0
#
# [5 rows x 45 columns]

# %%
#피처추가 함수 -> 나중에 더 추가할 예정
def add_features(df):

    #전공변환 - t/f로만 변경
    df['major type'] = df['major type'].str.startswith('복수')
    
    # hope_for_group - 조별활동 희망 여부+온오프라인. (네. 오프라인, 네. 온라인, 아니요.)
    # 1) 오프라인 여부
    df['offline'] = df['hope_for_group'].map({
        '네. 오프라인으로 참여하고 싶어요': 1,
        '네. 온라인으로 참여하고 싶어요': 0
    })
    df['offline'] = df['offline'].fillna(-1)
    
    # 2) 조별활동 여부
    df['hope_for_group'] = df['hope_for_group'].str.contains('네')
    
    #현재 수강과목 개수
    class_cols = ['class1','class2','class3','class4']
    df['class_cnt'] = df[class_cols].notna().sum(axis=1)
    
    #이전 수강 경험
    prev_cols = ['previous_class_3','previous_class_4','previous_class_5',
             'previous_class_6','previous_class_7','previous_class_8']

    # 이전 수강 경험 여부
    df['has_previous'] = df[prev_cols].notnull().any(axis=1).astype(int)
    
    #이전 수강 과목 개수 
    df['prev_class_cnt'] = (
        df[prev_cols]
        .stack()
        .str.count('000\d')     # 0001~0009 코드 개수 세기
        .groupby(level=0)
        .sum()
        .fillna(0)
        .astype(int)
    )
    
    # 수강자 수준 분류 
    level_map = {
        '0001': '기초',
        '0002': '기초',
        '0003': '기초',
        '0005': '기초',
        '0004': '중급',
        '0006': '중급',
        '0007': '중급',
        '0008': '중급'
    }
    
    def level_score(row):
        codes = (
            row.dropna()
            .str.findall(r'000\d')
            .explode()
        )
        
        if codes is None or len(codes)==0:
            return 0
        
        levels = codes.map(level_map).dropna()
        
        if '중급' in levels.values:
            return 2
        elif '기초' in levels.values:
            return 1
        else:
            return 0

    df['prev_level'] = df[prev_cols].apply(level_score, axis=1)
    
    #cert_cnt: 각자 가진 자격증 개수 카운트
    def clean_cert(x):
        if isinstance(x, list):
            x = ','.join(x)   # 리스트면 문자열로 합침
        
        x = str(x)
        
        invalid = {'없음','기타','준비중'}
        
        return [
            i.strip() for i in x.split(',')
            if i.strip() not in invalid
            and not i.strip().startswith('준비중')
            and i.strip()!='nan'
        ]

    df['cert_list'] = df['certificate_acquisition'].apply(clean_cert)
    df['cert_cnt'] = df['cert_list'].apply(len)
    df['has_cert'] = (df['cert_cnt'] > 0).astype(int)
    
    #데이터 관련 자격증이 있는지
    data_certs = {'ADsP','빅데이터 분석 기사','구글 애널리스트','태블로'}

    df['data_cert'] = df['cert_list'].apply(
        lambda x: any(cert in data_certs for cert in x)
    )
    
    #텍스트 길이
    df['why_len'] = df['whyBDA'].str.len()
    
    return df

df_train = add_features(df_train)
df_test = add_features(df_test)
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\d'
# <>:33: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/7x/ckht72xn7276hfpwcr1r7vwr0000gn/T/ipykernel_13191/3221170744.py:33: SyntaxWarning: invalid escape sequence '\d'
#   .str.count('000\d')     # 0001~0009 코드 개수 세기

# %%
#피처추가 함수 -> 나중에 더 추가할 예정
def text_features(df):
    def map_category(text):
        text = str(text)
        result = []
        
        if "분석" in text or "지식" in text or "역량" in text:
            result.append("분석")
            
        if "프로젝트" in text:
            result.append("프로젝트")
            
        if "공모전" in text:
            result.append("공모전")
            
        if "네트워크" in text or "인맥" in text:
            result.append("네트워크")
            
        if "전체" in text:
            result = ["분석","프로젝트","공모전","네트워크"]
        
        # 아무 것도 없을 때만 기타
        if len(result) == 0:
            result.append("기타")
            
        return result

    df["gain_clean"] = df["what_to_gain"].apply(map_category)
    del df["what_to_gain"]

    return df

df_train = text_features(df_train)
df_test = text_features(df_test)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

#-------------------
# 1. cert_list 처리
#-------------------
mlb_cert = MultiLabelBinarizer()

# train
cert_train = pd.DataFrame(
    mlb_cert.fit_transform(df_train['cert_list']),
    columns=mlb_cert.classes_,
    index=df_train.index
)

df_train = pd.concat([df_train, cert_train], axis=1)

# test
cert_test = pd.DataFrame(
    mlb_cert.transform(df_test['cert_list']),
    columns=mlb_cert.classes_,
    index=df_test.index
)

df_test = pd.concat([df_test, cert_test], axis=1)

#-------------------
# 2. desired_job 처리
#-------------------
df_train["desired_job_except_data"] = (
    df_train["desired_job_except_data"]
    .fillna("")
    .str.findall(r'\b([A-Z])\.')
)

df_test["desired_job_except_data"] = (
    df_test["desired_job_except_data"]
    .fillna("")
    .str.findall(r'\b([A-Z])\.')
)


mlb_job = MultiLabelBinarizer()

# train
job_train = pd.DataFrame(
    mlb_job.fit_transform(df_train["desired_job_except_data"]),
    columns=mlb_job.classes_,
    index=df_train.index
)

df_train = pd.concat([df_train, job_train], axis=1)

# test
job_test = pd.DataFrame(
    mlb_job.transform(df_test["desired_job_except_data"]),
    columns=mlb_job.classes_,
    index=df_test.index
)

df_test = pd.concat([df_test, job_test], axis=1)
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['2급)', 'AWS Certified Cloud Practitioner', 'Aws AI', 'DAsP', 'Dasp', 'MOS EXCEL EXPERT', 'MOS Master', 'OA 자격증', 'SAS Adanced', 'SAS Base', 'pc정비사 2급', '네트워크관리사 2급', '사조사 2급', '사조사2급', '사회조사분석가 2급', '사회조사분석사 2급', '사회조사분석사2급', '정보처리기능사', '정보처리산업기사', '컴퓨터 활용능력(1', '태블로 관련 자격증'] will be ignored
#   warnings.warn(

# %% [markdown]
# ### 실험 드랍

# %%
other_drop_cols = ['major type','major_data']

# %% [markdown]
# # 타겟/피처 분리

# %%
TARGET = 'completed'
X = df_train.drop(columns=[TARGET]).copy()
y = df_train[TARGET].astype(int).copy()
X_test = df_test.copy()

drop_cols = ['contest_award','idea_contest','contest_participation','class3','class4'] +other_drop_cols #거의 다 결측값

X.drop(columns=drop_cols,inplace=True)
X_test.drop(columns=drop_cols,inplace=True)

# %%
from sklearn.model_selection import StratifiedKFold

# -----------------------------
# 1. 컬럼 구분
# -----------------------------
cat_cols = X.select_dtypes(include=["object"]).columns.tolist()
num_cols = X.select_dtypes(exclude=["object"]).columns.tolist()

# 코드형 숫자 → 범주형 처리
code_like = ['generation','school1','class1','class2','time_input']
for c in code_like:
    if c in X.columns:
        cat_cols.append(c)
        if c in num_cols:
            num_cols.remove(c)

cat_cols = list(set(cat_cols))

# -----------------------------
# 2. 결측 처리
# -----------------------------
# categorical
for c in cat_cols:
    X[c] = X[c].fillna("UNK").astype(str)
    X_test[c] = X_test[c].fillna("UNK").astype(str)

# numeric
for c in num_cols:
    med = X[c].median()
    if pd.isna(med):
        med = 0
    X[c] = X[c].fillna(med)
    X_test[c] = X_test[c].fillna(med)

# -----------------------------
# 3. Target Encoding (CV 방식, leakage 방지)
# -----------------------------
skf_te = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

global_mean = y.mean()

for col in cat_cols:
    X[col] = X[col].astype(str)
    X_test[col] = X_test[col].astype(str)

    oof_col = np.zeros(len(X))
    test_col = np.zeros(len(X_test))

    for tr_idx, va_idx in skf_te.split(X, y):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr = y.iloc[tr_idx]

        # train fold에서만 mean 계산
        means = y_tr.groupby(X_tr[col]).mean()

        # validation fold에 매핑
        oof_col[va_idx] = X_va[col].map(means)

        # test는 fold별 평균 누적
        test_col += X_test[col].map(means).fillna(global_mean) / skf_te.n_splits

    # NaN → global mean
    X[col] = np.where(pd.isna(oof_col), global_mean, oof_col)
    X_test[col] = test_col

# %%
#타입 분리
cat_cols = X.select_dtypes(include=['object', 'bool']).columns.tolist()
num_cols = X.select_dtypes(include=['number']).columns.tolist()

print(cat_cols)
print(num_cols)
# Out:
# ['hope_for_group', 'data_cert']
# ['generation', 'school1', 'major1_1', 'major1_2', 'job', 'class1', 'class2', 're_registration', 'nationality', 'inflow_route', 'whyBDA', 'previous_class_3', 'previous_class_4', 'previous_class_5', 'previous_class_6', 'previous_class_7', 'previous_class_8', 'major_field', 'desired_career_path', 'completed_semester', 'project_type', 'time_input', 'desired_job', 'certificate_acquisition', 'desired_certificate', 'desired_job_except_data', 'incumbents_level', 'incumbents_lecture', 'incumbents_company_level', 'incumbents_lecture_type', 'incumbents_lecture_scale', 'incumbents_lecture_scale_reason', 'interested_company', 'expected_domain', 'onedayclass_topic', 'offline', 'class_cnt', 'has_previous', 'prev_class_cnt', 'prev_level', 'cert_list', 'cert_cnt', 'has_cert', 'why_len', 'gain_clean', 'ADsP', 'AWS', 'SQLD', '구글 애널리스트', '빅데이터 분석 기사', '정보처리기사', '컴퓨터활용능력', '태블로', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
#타입 분리
checkedcat_cols = X.select_dtypes(include=['object']).columns.tolist()
checkednum_cols = X.select_dtypes(include=['number']).columns.tolist()

print(checkedcat_cols)
print(checkednum_cols)
# Out:
# []
# ['generation', 'school1', 'major1_1', 'major1_2', 'job', 'class1', 'class2', 're_registration', 'nationality', 'inflow_route', 'whyBDA', 'previous_class_3', 'previous_class_4', 'previous_class_5', 'previous_class_6', 'previous_class_7', 'previous_class_8', 'major_field', 'desired_career_path', 'completed_semester', 'project_type', 'time_input', 'desired_job', 'certificate_acquisition', 'desired_certificate', 'desired_job_except_data', 'incumbents_level', 'incumbents_lecture', 'incumbents_company_level', 'incumbents_lecture_type', 'incumbents_lecture_scale', 'incumbents_lecture_scale_reason', 'interested_company', 'expected_domain', 'onedayclass_topic', 'offline', 'class_cnt', 'has_previous', 'prev_class_cnt', 'prev_level', 'cert_list', 'cert_cnt', 'has_cert', 'why_len', 'gain_clean', 'ADsP', 'AWS', 'SQLD', '구글 애널리스트', '빅데이터 분석 기사', '정보처리기사', '컴퓨터활용능력', '태블로', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

skf = StratifiedKFold(n_splits=7, shuffle=True, random_state=42)

oof_pred = np.zeros(len(X))
test_pred = np.zeros(len(X_test))

for fold, (tr_idx, va_idx) in enumerate(skf.split(X, y), 1):
    print(f"\n===== Fold {fold}/5 =====")

    X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
    y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]

    #0.39 의 역대 best (accuracy 0.55)
    model = xgb.XGBClassifier(
        n_estimators=20,
        learning_rate=0.03,

        # 핵심 규제들
        max_depth=3,
        min_child_weight=5,
        gamma=1.0,

        subsample=0.6,
        colsample_bytree=0.6,

        reg_alpha=5,
        reg_lambda=30,

        objective="binary:logistic",
        eval_metric="aucpr",
        tree_method="hist",
        #early_stopping_rounds=5,
        random_state=42
        
    )
    model.fit(
        X_tr, y_tr,
        eval_set=[(X_tr,y_tr),(X_va,y_va)],
        verbose=False
    )


    oof_pred[va_idx] = model.predict_proba(X_va)[:, 1]
    test_pred += model.predict_proba(X_test)[:, 1] / skf.n_splits
# Out:
# ===== Fold 1/5 =====
#
# ===== Fold 2/5 =====
#
# ===== Fold 3/5 =====
#
# ===== Fold 4/5 =====
#
# ===== Fold 5/5 =====
#
# ===== Fold 6/5 =====
#
# ===== Fold 7/5 =====

# %%
# -----------------------------
# threshold tuning (OOF 기준)
# -----------------------------
import numpy as np
best_f1, best_th = -1, 0.5

for th in np.arange(0.05, 0.96, 0.01):
    pred = (oof_pred >= th).astype(int)
    f1 = f1_score(y, pred)
    if f1 > best_f1:
        best_f1, best_th = f1, th

print("OOF Best F1:", best_f1)
print("Best threshold:", best_th)

pred_test = (test_pred >= best_th).astype(int)
print("test pred distribution:", np.unique(pred_test, return_counts=True))
# Out:
# OOF Best F1: 0.4916030534351145
# Best threshold: 0.29000000000000004
# test pred distribution: (array([0, 1]), array([387, 427]))

# %%
import matplotlib.pyplot as plt

results = model.evals_result()

epochs = len(results['validation_0']['aucpr'])

x_axis = range(epochs)

plt.figure()
plt.plot(x_axis, results['validation_0']['aucpr'], label='Train')
plt.plot(x_axis, results['validation_1']['aucpr'], label='Valid')
plt.legend()
plt.title('XGBoost AUC')
plt.show()

# %%
print(np.unique(oof_label, return_counts=True))
# Out:
# (array([0, 1]), array([316, 432]))

# %%
import matplotlib.pyplot as plt

results = model.evals_result()

epochs = len(results['validation_0']['logloss'])

x_axis = range(epochs)

plt.figure()
plt.plot(x_axis, results['validation_0']['logloss'], label='Train')
plt.plot(x_axis, results['validation_1']['logloss'], label='Valid')
plt.legend()
plt.title('XGBoost AUC')
plt.show()

# %%
print(np.percentile(oof_pred,[0,25,50,75,90,95,99]))
# Out:
# [0.27042162 0.28373659 0.29339175 0.30553217 0.31227277 0.31463081
#  0.31751536]

# %%
from sklearn.metrics import classification_report

oof_label = (oof_pred >= best_th).astype(int)

print(classification_report(y, oof_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.48      0.60       525
#            1       0.37      0.72      0.49       223
#
#     accuracy                           0.55       748
#    macro avg       0.59      0.60      0.55       748
# weighted avg       0.68      0.55      0.57       748

# %%
plt.hist(oof_pred,bins=50)
plt.title("OOF prediction distribution")
plt.show()

# %% [markdown]
# ## Optuna 적용해서 최적화

# %%
import optuna
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

skf = StratifiedKFold(n_splits=7, shuffle=True, random_state=42)

def objective(trial):

    params = {
        "n_estimators": trial.suggest_int("n_estimators", 5, 45, step=5),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),

        "max_depth": trial.suggest_int("max_depth", 2, 6),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "gamma": trial.suggest_float("gamma", 0, 5),

        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),

        "reg_alpha": trial.suggest_float("reg_alpha", 10, 50),
        "reg_lambda": trial.suggest_float("reg_lambda", 10, 50),

        "objective": "binary:logistic",
        "eval_metric": "logloss",
        "tree_method": "hist",
        "random_state": 42,
        "use_label_encoder": False
    }

    oof_pred = np.zeros(len(X))

    for tr_idx, va_idx in skf.split(X, y):

        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]

        model = xgb.XGBClassifier(**params)

        model.fit(
            X_tr, y_tr,
            eval_set=[(X_va, y_va)],
            #early_stopping_rounds=20,
            verbose=False
        )

        oof_pred[va_idx] = model.predict_proba(X_va)[:,1]

    # threshold 0.5 기준 F1
    oof_label = (oof_pred > 0.5).astype(int)
    score = f1_score(y, oof_label)

    return score


study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print("Best F1:", study.best_value)
print("Best params:", study.best_params)
# Out:
# [I 2026-02-06 15:23:44,367] A new study created in memory with name: no-name-a014b158-1748-41c5-9560-1d042bfd1556
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:44,545] Trial 0 finished with value: 0.0 and parameters: {'n_estimators': 15, 'learning_rate': 0.10303098286026975, 'max_depth': 3, 'min_child_weight': 9, 'gamma': 0.37841475006720804, 'subsample': 0.5472343752859142, 'colsample_bytree': 0.560057509806709, 'reg_alpha': 47.4720773386117, 'reg_lambda': 43.03547788910737}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:44,740] Trial 1 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.11262821961463688, 'max_depth': 2, 'min_child_weight': 6, 'gamma': 1.7549107045720913, 'subsample': 0.5028177059089707, 'colsample_bytree': 0.5640737086652379, 'reg_alpha': 22.372695297360963, 'reg_lambda': 13.560212483420973}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:44,930] Trial 2 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.011762793703407439, 'max_depth': 5, 'min_child_weight': 5, 'gamma': 2.4212393062685225, 'subsample': 0.9421701244572873, 'colsample_bytree': 0.6462142163194509, 'reg_alpha': 45.65876825353, 'reg_lambda': 48.01761368552079}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:45,094] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 20, 'learning_rate': 0.1309176924785695, 'max_depth': 6, 'min_child_weight': 2, 'gamma': 0.5937577303835168, 'subsample': 0.7955001864050457, 'colsample_bytree': 0.5641749659498998, 'reg_alpha': 22.499255288847607, 'reg_lambda': 40.51069341336468}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:45,314] Trial 4 finished with value: 0.0 and parameters: {'n_estimators': 40, 'learning_rate': 0.11402162689743338, 'max_depth': 2, 'min_child_weight': 7, 'gamma': 1.120669142207279, 'subsample': 0.6676569687485698, 'colsample_bytree': 0.749775765067386, 'reg_alpha': 37.77625202770975, 'reg_lambda': 21.33393275622932}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:45,476] Trial 5 finished with value: 0.0 and parameters: {'n_estimators': 20, 'learning_rate': 0.06395282785303848, 'max_depth': 6, 'min_child_weight': 4, 'gamma': 1.7969860276773426, 'subsample': 0.8843902220386533, 'colsample_bytree': 0.5308901683123726, 'reg_alpha': 11.870809293860995, 'reg_lambda': 31.046066412903933}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:45,659] Trial 6 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.050174344302122184, 'max_depth': 3, 'min_child_weight': 4, 'gamma': 2.7801540862555445, 'subsample': 0.708954783893305, 'colsample_bytree': 0.505927585655235, 'reg_alpha': 40.03822089260104, 'reg_lambda': 43.607304660905726}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:45,952] Trial 7 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.06701170774280463, 'max_depth': 3, 'min_child_weight': 3, 'gamma': 1.131585216937624, 'subsample': 0.563360587424287, 'colsample_bytree': 0.9859189758740613, 'reg_alpha': 41.40659679367011, 'reg_lambda': 42.412993666140075}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:46,107] Trial 8 finished with value: 0.0 and parameters: {'n_estimators': 20, 'learning_rate': 0.048198203527226764, 'max_depth': 6, 'min_child_weight': 7, 'gamma': 1.668923602019885, 'subsample': 0.6351011116962565, 'colsample_bytree': 0.5997440027430712, 'reg_alpha': 35.13299170684916, 'reg_lambda': 15.922635694907417}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:46,276] Trial 9 finished with value: 0.0 and parameters: {'n_estimators': 25, 'learning_rate': 0.01827925223103715, 'max_depth': 6, 'min_child_weight': 5, 'gamma': 4.207912493125033, 'subsample': 0.835900530800224, 'colsample_bytree': 0.5473413141460712, 'reg_alpha': 30.622408850386478, 'reg_lambda': 26.26726583565308}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:46,397] Trial 10 finished with value: 0.0 and parameters: {'n_estimators': 5, 'learning_rate': 0.02942155472934504, 'max_depth': 4, 'min_child_weight': 10, 'gamma': 0.15988103419366495, 'subsample': 0.5828750853996116, 'colsample_bytree': 0.9267077895756569, 'reg_alpha': 49.10926213866013, 'reg_lambda': 35.149706115826014}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:46,517] Trial 11 finished with value: 0.0 and parameters: {'n_estimators': 5, 'learning_rate': 0.19479124836534997, 'max_depth': 2, 'min_child_weight': 10, 'gamma': 3.452384599177379, 'subsample': 0.5093597032658613, 'colsample_bytree': 0.6904515257794519, 'reg_alpha': 20.929050128791157, 'reg_lambda': 12.945264158128033}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:46,775] Trial 12 finished with value: 0.0 and parameters: {'n_estimators': 45, 'learning_rate': 0.10414735778177893, 'max_depth': 3, 'min_child_weight': 8, 'gamma': 0.6357742803861115, 'subsample': 0.5211599433973817, 'colsample_bytree': 0.8601195259967434, 'reg_alpha': 21.430091702354275, 'reg_lambda': 21.859465098125717}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:46,931] Trial 13 finished with value: 0.0 and parameters: {'n_estimators': 10, 'learning_rate': 0.19810043655761495, 'max_depth': 2, 'min_child_weight': 8, 'gamma': 2.1609583315195775, 'subsample': 0.6034288681340709, 'colsample_bytree': 0.6763194366298448, 'reg_alpha': 27.82992495662754, 'reg_lambda': 34.399787287533954}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:47,100] Trial 14 finished with value: 0.0 and parameters: {'n_estimators': 15, 'learning_rate': 0.07953179506881472, 'max_depth': 4, 'min_child_weight': 9, 'gamma': 3.160224077322477, 'subsample': 0.7321185497396443, 'colsample_bytree': 0.7867691789514517, 'reg_alpha': 12.228631248232759, 'reg_lambda': 48.567021921970664}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:47,350] Trial 15 finished with value: 0.0 and parameters: {'n_estimators': 35, 'learning_rate': 0.033166340659570664, 'max_depth': 3, 'min_child_weight': 6, 'gamma': 0.005154781192410418, 'subsample': 0.5226702962143042, 'colsample_bytree': 0.6360479513682955, 'reg_alpha': 27.27700960991029, 'reg_lambda': 10.370391952958519}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:47,511] Trial 16 finished with value: 0.0 and parameters: {'n_estimators': 15, 'learning_rate': 0.1308877136713108, 'max_depth': 2, 'min_child_weight': 1, 'gamma': 1.4059467148587586, 'subsample': 0.9982547690334984, 'colsample_bytree': 0.7546534970270298, 'reg_alpha': 16.85916845869272, 'reg_lambda': 18.352354426229276}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:47,711] Trial 17 finished with value: 0.0 and parameters: {'n_estimators': 25, 'learning_rate': 0.09423949448763023, 'max_depth': 3, 'min_child_weight': 7, 'gamma': 4.7556496583169015, 'subsample': 0.6657113811792623, 'colsample_bytree': 0.585514118543018, 'reg_alpha': 31.879129930565988, 'reg_lambda': 25.83775967868695}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:47,958] Trial 18 finished with value: 0.0 and parameters: {'n_estimators': 35, 'learning_rate': 0.16277741522647055, 'max_depth': 4, 'min_child_weight': 9, 'gamma': 0.6296631504556438, 'subsample': 0.5600297027611681, 'colsample_bytree': 0.7015627828489468, 'reg_alpha': 24.765904554054018, 'reg_lambda': 38.07232649843755}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:48,156] Trial 19 finished with value: 0.0 and parameters: {'n_estimators': 15, 'learning_rate': 0.0377742716997326, 'max_depth': 2, 'min_child_weight': 6, 'gamma': 2.0071152262748924, 'subsample': 0.6200171223229802, 'colsample_bytree': 0.5036388075141898, 'reg_alpha': 16.310013937182642, 'reg_lambda': 27.801375529236694}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:48,314] Trial 20 finished with value: 0.0 and parameters: {'n_estimators': 10, 'learning_rate': 0.08063085574329244, 'max_depth': 4, 'min_child_weight': 9, 'gamma': 1.0630109852458185, 'subsample': 0.7774296385054377, 'colsample_bytree': 0.605631228420391, 'reg_alpha': 44.65958522155972, 'reg_lambda': 32.11658446153835}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:23:48,526] Trial 21 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.01482750329857822, 'max_depth': 5, 'min_child_weight': 5, 'gamma': 2.497545715130034, 'subsample': 0.9910010485528458, 'colsample_bytree': 0.6269519270343434, 'reg_alpha': 48.06828384814915, 'reg_lambda': 49.964734363563025}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:23:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# ...
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:02,501] Trial 92 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.03051717706574196, 'max_depth': 6, 'min_child_weight': 6, 'gamma': 4.077133269796585, 'subsample': 0.8025563133719094, 'colsample_bytree': 0.5619141245588257, 'reg_alpha': 22.604736225349487, 'reg_lambda': 21.628575573691894}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:02,692] Trial 93 finished with value: 0.0 and parameters: {'n_estimators': 25, 'learning_rate': 0.013576702819279862, 'max_depth': 6, 'min_child_weight': 4, 'gamma': 4.459909166738194, 'subsample': 0.8228756916733636, 'colsample_bytree': 0.5117074282957427, 'reg_alpha': 28.95631246345433, 'reg_lambda': 26.967925353144075}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:02,901] Trial 94 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.019856266848916445, 'max_depth': 6, 'min_child_weight': 9, 'gamma': 3.786036027425394, 'subsample': 0.8588780632369539, 'colsample_bytree': 0.5467632394246273, 'reg_alpha': 30.91242481657942, 'reg_lambda': 24.726075182025355}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:03,091] Trial 95 finished with value: 0.0 and parameters: {'n_estimators': 25, 'learning_rate': 0.011346929748124686, 'max_depth': 6, 'min_child_weight': 8, 'gamma': 2.1976073865859154, 'subsample': 0.5468125830427537, 'colsample_bytree': 0.5304494758786106, 'reg_alpha': 38.95607231819544, 'reg_lambda': 17.044640536765737}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:03,274] Trial 96 finished with value: 0.0 and parameters: {'n_estimators': 20, 'learning_rate': 0.052065179312668644, 'max_depth': 5, 'min_child_weight': 5, 'gamma': 4.907009539052941, 'subsample': 0.9169079343512678, 'colsample_bytree': 0.6313819415793599, 'reg_alpha': 49.96631067901402, 'reg_lambda': 20.089411411544646}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:03,488] Trial 97 finished with value: 0.0 and parameters: {'n_estimators': 30, 'learning_rate': 0.0981217871725736, 'max_depth': 2, 'min_child_weight': 7, 'gamma': 0.29472449804456635, 'subsample': 0.791644519023473, 'colsample_bytree': 0.6863547530499662, 'reg_alpha': 37.21782404271668, 'reg_lambda': 38.357459949866666}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:03,714] Trial 98 finished with value: 0.0 and parameters: {'n_estimators': 35, 'learning_rate': 0.045681529447566545, 'max_depth': 4, 'min_child_weight': 3, 'gamma': 0.10997195579881813, 'subsample': 0.555037342308014, 'colsample_bytree': 0.5094348982391841, 'reg_alpha': 35.131727703498484, 'reg_lambda': 11.19654607898486}. Best is trial 0 with value: 0.0.
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [15:24:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2026-02-06 15:24:03,983] Trial 99 finished with value: 0.0 and parameters: {'n_estimators': 45, 'learning_rate': 0.06880201898641847, 'max_depth': 6, 'min_child_weight': 4, 'gamma': 3.446721662519025, 'subsample': 0.5713579930444959, 'colsample_bytree': 0.5729750691577244, 'reg_alpha': 26.49563051077785, 'reg_lambda': 43.30328028251828}. Best is trial 0 with value: 0.0.
# Best F1: 0.0
# Best params: {'n_estimators': 15, 'learning_rate': 0.10303098286026975, 'max_depth': 3, 'min_child_weight': 9, 'gamma': 0.37841475006720804, 'subsample': 0.5472343752859142, 'colsample_bytree': 0.560057509806709, 'reg_alpha': 47.4720773386117, 'reg_lambda': 43.03547788910737}

# %%
# Optuna best params 가져오기
best_params = study.best_params

# 고정 파라미터 추가
best_params.update({
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "tree_method": "hist",
    "random_state": 42
})

# 한 fold만 예시로 시각화 (보통 1st fold)
tr_idx, va_idx = next(skf.split(X, y))

X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]

model = xgb.XGBClassifier(**best_params)

model.fit(
    X_tr, y_tr,
    eval_set=[(X_tr, y_tr), (X_va, y_va)],
    verbose=False
)

# 학습 로그 가져오기
results = model.evals_result()

train_loss = results['validation_0']['logloss']
valid_loss = results['validation_1']['logloss']

# Plot
plt.figure()
plt.plot(train_loss, label="Train")
plt.plot(valid_loss, label="Validation")
plt.xlabel("Boosting Round")
plt.ylabel("LogLoss")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %% [markdown]
# ## 제출

# %%
from datetime import datetime

sub = pd.read_csv("OriginalData/sample_submission.csv")
sub["completed"] = pred_test

now = datetime.now().strftime("%Y%m%d_%H%M")
filename = f"Submit/submit_xgb{now}.csv"
print(filename)
sub.to_csv(filename, index=False)
# Out:
# Submit/submit_xgb20260206_1505.csv

# %%
print(y.mean())
# Out:
# 0.29812834224598933
